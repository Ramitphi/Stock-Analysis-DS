# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('E:\ML INtern\BAJFINANCE.csv')

# %%
df.head()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  BAJFINANCE     EQ  15-May-2017     1314.75      1323.0      1348.5
# 1  BAJFINANCE     EQ  16-May-2017     1332.95      1337.4      1358.8
# 2  BAJFINANCE     EQ  17-May-2017     1347.75      1350.0      1374.0
# 3  BAJFINANCE     EQ  18-May-2017     1324.80      1299.0      1343.0
# 4  BAJFINANCE     EQ  19-May-2017     1314.55      1324.0      1333.9
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0    1317.65      1332.0      1332.95        1335.96                 634195
# 1    1327.20      1346.0      1347.75        1344.96                 788530
# 2    1297.50      1320.0      1324.80        1343.51                2408302
# 3    1296.05      1310.7      1314.55        1325.97                1210985
# 4    1265.55      1288.0      1289.15        1295.81                1167010
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 15 columns):
# Symbol                    495 non-null object
# Series                    495 non-null object
# Date                      495 non-null datetime64[ns]
# Prev Close                495 non-null float64
# Open Price                495 non-null float64
# High Price                495 non-null float64
# Low Price                 495 non-null float64
# Last Price                495 non-null float64
# Close Price               495 non-null float64
# Average Price             495 non-null float64
# Total Traded Quantity     495 non-null int64
# Turnover                  495 non-null float64
# No. of Trades             495 non-null int64
# Deliverable Qty           495 non-null int64
# % Dly Qt to Traded Qty    495 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(2)
# memory usage: 58.1+ KB

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#                 Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15  BAJFINANCE     EQ     1314.75      1323.0      1348.5    1317.65
# 2017-05-16  BAJFINANCE     EQ     1332.95      1337.4      1358.8    1327.20
# 2017-05-17  BAJFINANCE     EQ     1347.75      1350.0      1374.0    1297.50
# 2017-05-18  BAJFINANCE     EQ     1324.80      1299.0      1343.0    1296.05
# 2017-05-19  BAJFINANCE     EQ     1314.55      1324.0      1333.9    1265.55
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15      1332.0      1332.95        1335.96                 634195
# 2017-05-16      1346.0      1347.75        1344.96                 788530
# 2017-05-17      1320.0      1324.80        1343.51                2408302
# 2017-05-18      1310.7      1314.55        1325.97                1210985
# 2017-05-19      1288.0      1289.15        1295.81                1167010
#
# ...

# %%
df['Close Price'].plot()

# %%
df['Daily per change']=df['Close Price'].pct_change()

# %%
df.head()
# Out:
#                 Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15  BAJFINANCE     EQ     1314.75      1323.0      1348.5    1317.65
# 2017-05-16  BAJFINANCE     EQ     1332.95      1337.4      1358.8    1327.20
# 2017-05-17  BAJFINANCE     EQ     1347.75      1350.0      1374.0    1297.50
# 2017-05-18  BAJFINANCE     EQ     1324.80      1299.0      1343.0    1296.05
# 2017-05-19  BAJFINANCE     EQ     1314.55      1324.0      1333.9    1265.55
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15      1332.0      1332.95        1335.96                 634195
# 2017-05-16      1346.0      1347.75        1344.96                 788530
# 2017-05-17      1320.0      1324.80        1343.51                2408302
# 2017-05-18      1310.7      1314.55        1325.97                1210985
# 2017-05-19      1288.0      1289.15        1295.81                1167010
#
# ...

# %%
df['Daily per change'].iloc[0]=0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.head()
# Out:
#                 Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15  BAJFINANCE     EQ     1314.75      1323.0      1348.5    1317.65
# 2017-05-16  BAJFINANCE     EQ     1332.95      1337.4      1358.8    1327.20
# 2017-05-17  BAJFINANCE     EQ     1347.75      1350.0      1374.0    1297.50
# 2017-05-18  BAJFINANCE     EQ     1324.80      1299.0      1343.0    1296.05
# 2017-05-19  BAJFINANCE     EQ     1314.55      1324.0      1333.9    1265.55
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15      1332.0      1332.95        1335.96                 634195
# 2017-05-16      1346.0      1347.75        1344.96                 788530
# 2017-05-17      1320.0      1324.80        1343.51                2408302
# 2017-05-18      1310.7      1314.55        1325.97                1210985
# 2017-05-19      1288.0      1289.15        1295.81                1167010
#
# ...

# %%
plt.stem(df.index,df['Close Price'])
plt.xticks(rotation=60)
# Out:
# (array([736511., 736603., 736695., 736785., 736876., 736968., 737060.,
#         737150.]), <a list of 8 Text xticklabel objects>)

# %%
plt.plot(df.index,df['Total Traded Quantity'])
plt.xticks(rotation=60)
# Out:
# (array([736511., 736603., 736695., 736785., 736876., 736968., 737060.,
#         737150.]), <a list of 8 Text xticklabel objects>)

# %%
(df['Daily per change']).max()
# Out:
# 0.10965512275901812

# %%
def set_trend(row):
    if row["Daily per change"] >=-0.5 and row['Daily per change']<=0.5:
        return "Slight or No change"
    if row["Daily per change"] >= 0.5 and row['Daily per change']<=1:
        return "Slight Positive"
    if row["Daily per change"] >=-1 and row['Daily per change']<=-0.5:
        return "Slight Negative"
    elif row["Daily per change"] >=1 and row['Daily per change']<=3:
        return "Positive"
    elif row["Daily per change"] >=-3 and row['Daily per change']<=-1:
        return "Negative"
    elif row["Daily per change"] >= 3 and row['Daily per change']<= 7:
        return "Among Top Gainers"
    elif row["Daily per change"] >= -7 and row['Daily per change']<= -3:
        return "Among Top Losers"
    elif row["Daily per change"] >=7:
        return "Bull run"
    elif row['Daily per change']<=-7:
        return "Bear Drop"
df = df.assign(Trend=df.apply(set_trend, axis=1))

print(df)
# Out:
#                 Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15  BAJFINANCE     EQ     1314.75     1323.00     1348.50    1317.65
# 2017-05-16  BAJFINANCE     EQ     1332.95     1337.40     1358.80    1327.20
# 2017-05-17  BAJFINANCE     EQ     1347.75     1350.00     1374.00    1297.50
# 2017-05-18  BAJFINANCE     EQ     1324.80     1299.00     1343.00    1296.05
# 2017-05-19  BAJFINANCE     EQ     1314.55     1324.00     1333.90    1265.55
# 2017-05-22  BAJFINANCE     EQ     1289.15     1299.00     1304.00    1237.35
# 2017-05-23  BAJFINANCE     EQ     1242.15     1249.90     1265.00    1190.55
# 2017-05-24  BAJFINANCE     EQ     1233.75     1234.00     1254.90    1210.00
# 2017-05-25  BAJFINANCE     EQ     1224.35     1230.00     1268.00    1228.25
# 2017-05-26  BAJFINANCE     EQ     1258.85     1261.70     1326.70    1261.70
# 2017-05-29  BAJFINANCE     EQ     1317.80     1319.40     1333.00    1301.90
# ...

# %%
plt.hist(df['Daily per change'])
plt.xticks(rotation=60)
# Out:
# (array([-0.1  , -0.075, -0.05 , -0.025,  0.   ,  0.025,  0.05 ,  0.075,
#          0.1  ,  0.125]), <a list of 10 Text xticklabel objects>)

# %%
df1=pd.read_csv('E:\Small_Cap\LUXIND.csv')

# %%
df2=pd.read_csv('E:\Small_Cap\JETAIRWAYS.csv')
df3=pd.read_csv('E:\Small_Cap\RAYMOND.csv')
df4=pd.read_csv('E:\Small_Cap\BOMDYEING.csv')
df5=pd.read_csv('E:\Small_Cap\PVR.csv')

# %%
df1=df1[df1['Series']=='EQ']

# %%
df2=df2[df2['Series']=='EQ']
df3=df3[df3['Series']=='EQ']
df4=df4[df4['Series']=='EQ']
df5=df5[df5['Series']=='EQ']

# %%
df1['Date']=pd.to_datetime(df1['Date'])
df2['Date']=pd.to_datetime(df2['Date'])
df3['Date']=pd.to_datetime(df3['Date'])
df4['Date']=pd.to_datetime(df4['Date'])
df5['Date']=pd.to_datetime(df5['Date'])

# %%
df1.set_index(df1['Date'],inplace=True)
df2.set_index(df2['Date'],inplace=True)
df3.set_index(df3['Date'],inplace=True)
df4.set_index(df4['Date'],inplace=True)
df5.set_index(df5['Date'],inplace=True)

# %%
final_df=df1['Close Price']

# %%
final_df=pd.concat([final_df,df2['Close Price']],axis=1)

# %%
final_df=pd.concat([final_df,df3['Close Price']],axis=1)

# %%
final_df=pd.concat([final_df,df4['Close Price']],axis=1)

# %%
final_df=pd.concat([final_df,df5['Close Price']],axis=1)

# %%
final_df
# Out:
#             Close Price  Close Price  Close Price  Close Price  Close Price
# Date
# 2017-05-15       819.60       527.50       772.80        82.20      1524.95
# 2017-05-16       817.50       534.15       785.00        83.40      1539.00
# 2017-05-17       819.80       528.90       783.65        82.25      1530.30
# 2017-05-18       820.05       522.70       746.95        78.95      1515.05
# 2017-05-19       817.80       520.40       723.10        77.15      1513.55
# 2017-05-22       817.05       475.65       715.95        74.00      1481.00
# 2017-05-23       807.30       472.85       699.55        70.45      1496.45
# 2017-05-24       792.00       464.80       662.25        66.95      1450.00
# 2017-05-25       807.30       468.95       678.30        69.85      1461.15
# 2017-05-26       811.45       483.40       721.15        73.00      1471.50
# 2017-05-29       799.55       474.60       695.50        70.50      1472.85
# ...

# %%
final_df.columns
# Out:
# Index(['Close Price', 'Close Price', 'Close Price', 'Close Price',
#        'Close Price'],
#       dtype='object')

# %%
#final_df.rename(columns={'Close Price':'LUXIND',
 #                         'Close Price':'JETAIRWAYS',
  #                        'Close Price':'RAYMOND','Close Price':'BOMDYEING','Close Price':'PVR'}, 
   #              inplace=True)

# %%
final_df.columns=['LUXIND','JETAIRWAYS','RAYMOND','BOMDYEING','PVR']

# %%
final_df
# Out:
#              LUXIND  JETAIRWAYS  RAYMOND  BOMDYEING      PVR
# Date
# 2017-05-15   819.60      527.50   772.80      82.20  1524.95
# 2017-05-16   817.50      534.15   785.00      83.40  1539.00
# 2017-05-17   819.80      528.90   783.65      82.25  1530.30
# 2017-05-18   820.05      522.70   746.95      78.95  1515.05
# 2017-05-19   817.80      520.40   723.10      77.15  1513.55
# 2017-05-22   817.05      475.65   715.95      74.00  1481.00
# 2017-05-23   807.30      472.85   699.55      70.45  1496.45
# 2017-05-24   792.00      464.80   662.25      66.95  1450.00
# 2017-05-25   807.30      468.95   678.30      69.85  1461.15
# 2017-05-26   811.45      483.40   721.15      73.00  1471.50
# 2017-05-29   799.55      474.60   695.50      70.50  1472.85
# 2017-05-30   792.85      459.65   695.45      71.80  1447.90
# 2017-05-31   796.75      477.90   694.20      71.35  1454.95
# 2017-06-01   789.15      484.50   693.90      70.95  1455.70
# ...

# %%
pr_change=final_df['LUXIND'].pct_change()

# %%
pr_change=pd.concat([pr_change,final_df['JETAIRWAYS'].pct_change()],axis=1)
pr_change=pd.concat([pr_change,final_df['RAYMOND'].pct_change()],axis=1)
pr_change=pd.concat([pr_change,final_df['BOMDYEING'].pct_change()],axis=1)
pr_change=pd.concat([pr_change,final_df['PVR'].pct_change()],axis=1)

# %%
pr_change
# Out:
#               LUXIND  JETAIRWAYS   RAYMOND  BOMDYEING       PVR
# Date
# 2017-05-15       NaN         NaN       NaN        NaN       NaN
# 2017-05-16 -0.002562    0.012607  0.015787   0.014599  0.009213
# 2017-05-17  0.002813   -0.009829 -0.001720  -0.013789 -0.005653
# 2017-05-18  0.000305   -0.011722 -0.046832  -0.040122 -0.009965
# 2017-05-19 -0.002744   -0.004400 -0.031930  -0.022799 -0.000990
# 2017-05-22 -0.000917   -0.085992 -0.009888  -0.040830 -0.021506
# 2017-05-23 -0.011933   -0.005887 -0.022907  -0.047973  0.010432
# 2017-05-24 -0.018952   -0.017024 -0.053320  -0.049681 -0.031040
# 2017-05-25  0.019318    0.008929  0.024236   0.043316  0.007690
# 2017-05-26  0.005141    0.030814  0.063173   0.045097  0.007083
# 2017-05-29 -0.014665   -0.018204 -0.035568  -0.034247  0.000917
# 2017-05-30 -0.008380   -0.031500 -0.000072   0.018440 -0.016940
# 2017-05-31  0.004919    0.039704 -0.001797  -0.006267  0.004869
# 2017-06-01 -0.009539    0.013810 -0.000432  -0.005606  0.000515
# ...

# %%
pr_change.dropna(how='any')
# Out:
#               LUXIND  JETAIRWAYS   RAYMOND  BOMDYEING       PVR
# Date
# 2017-05-16 -0.002562    0.012607  0.015787   0.014599  0.009213
# 2017-05-17  0.002813   -0.009829 -0.001720  -0.013789 -0.005653
# 2017-05-18  0.000305   -0.011722 -0.046832  -0.040122 -0.009965
# 2017-05-19 -0.002744   -0.004400 -0.031930  -0.022799 -0.000990
# 2017-05-22 -0.000917   -0.085992 -0.009888  -0.040830 -0.021506
# 2017-05-23 -0.011933   -0.005887 -0.022907  -0.047973  0.010432
# 2017-05-24 -0.018952   -0.017024 -0.053320  -0.049681 -0.031040
# 2017-05-25  0.019318    0.008929  0.024236   0.043316  0.007690
# 2017-05-26  0.005141    0.030814  0.063173   0.045097  0.007083
# 2017-05-29 -0.014665   -0.018204 -0.035568  -0.034247  0.000917
# 2017-05-30 -0.008380   -0.031500 -0.000072   0.018440 -0.016940
# 2017-05-31  0.004919    0.039704 -0.001797  -0.006267  0.004869
# 2017-06-01 -0.009539    0.013810 -0.000432  -0.005606  0.000515
# 2017-06-02  0.035925    0.000722  0.012610  -0.014094  0.001443
# ...

# %%
g = sns.PairGrid(pr_change)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
pr_change['avg']=pr_change['PVR'].rolling(window=7).mean()

# %%
pr_change
# Out:
#               LUXIND  JETAIRWAYS   RAYMOND  BOMDYEING       PVR  volatility  \
# Date
# 2017-05-15       NaN         NaN       NaN        NaN       NaN         NaN
# 2017-05-16 -0.002562    0.012607  0.015787   0.014599  0.009213         NaN
# 2017-05-17  0.002813   -0.009829 -0.001720  -0.013789 -0.005653         NaN
# 2017-05-18  0.000305   -0.011722 -0.046832  -0.040122 -0.009965         NaN
# 2017-05-19 -0.002744   -0.004400 -0.031930  -0.022799 -0.000990         NaN
# 2017-05-22 -0.000917   -0.085992 -0.009888  -0.040830 -0.021506         NaN
# 2017-05-23 -0.011933   -0.005887 -0.022907  -0.047973  0.010432         NaN
# 2017-05-24 -0.018952   -0.017024 -0.053320  -0.049681 -0.031040   -0.007073
# 2017-05-25  0.019318    0.008929  0.024236   0.043316  0.007690   -0.007290
# 2017-05-26  0.005141    0.030814  0.063173   0.045097  0.007083   -0.005471
# 2017-05-29 -0.014665   -0.018204 -0.035568  -0.034247  0.000917   -0.003916
# ...

# %%
pr_change['std']=pr_change['PVR'].rolling(window=7).std()

# %%
pr_change.drop(columns='volatility')
# Out:
#               LUXIND  JETAIRWAYS   RAYMOND  BOMDYEING       PVR       avg  \
# Date
# 2017-05-15       NaN         NaN       NaN        NaN       NaN       NaN
# 2017-05-16 -0.002562    0.012607  0.015787   0.014599  0.009213       NaN
# 2017-05-17  0.002813   -0.009829 -0.001720  -0.013789 -0.005653       NaN
# 2017-05-18  0.000305   -0.011722 -0.046832  -0.040122 -0.009965       NaN
# 2017-05-19 -0.002744   -0.004400 -0.031930  -0.022799 -0.000990       NaN
# 2017-05-22 -0.000917   -0.085992 -0.009888  -0.040830 -0.021506       NaN
# 2017-05-23 -0.011933   -0.005887 -0.022907  -0.047973  0.010432       NaN
# 2017-05-24 -0.018952   -0.017024 -0.053320  -0.049681 -0.031040 -0.007073
# 2017-05-25  0.019318    0.008929  0.024236   0.043316  0.007690 -0.007290
# 2017-05-26  0.005141    0.030814  0.063173   0.045097  0.007083 -0.005471
# 2017-05-29 -0.014665   -0.018204 -0.035568  -0.034247  0.000917 -0.003916
# 2017-05-30 -0.008380   -0.031500 -0.000072   0.018440 -0.016940 -0.006195
# ...

# %%
pr_change['avg'].plot(legend=True)
pr_change['std'].plot(legend=True)
